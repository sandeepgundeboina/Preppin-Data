# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df=pd.read_csv('PD 2022 Wk 1 Input - Input.csv')
df
# Out:
#        id pupil first name pupil last name  gender Date of Birth  \
# 0       1            Ronna         Nellies  Female    12/21/2013
# 1       2            Rusty       Andriulis    Male     7/21/2012
# 2       3          Roberta       Oakeshott  Female     12/4/2011
# 3       4             Lola       Rubinfajn    Male     6/29/2012
# 4       5           Kamila        Benedtti  Female     7/10/2012
# ..    ...              ...             ...     ...           ...
# 995   996          Ninetta         Worling  Female     2/15/2015
# 996   997         Stanford          Tinton  Female      4/9/2013
# 997   998            Ertha         MacCook    Male    12/14/2013
# 998   999           Lawton         Randles  Female    12/12/2011
# 999  1000         Engracia         Pashbee  Female     9/23/2013
#
#     Parental Contact Name_1 Parental Contact Name_2  \
# 0                   Purcell                   Ketti
# 1                   Vassili                    Rivi
# ...

# %%
df['Pupils Name']=df['pupil last name']+","+df['pupil first name']

# %%
df['Parental Contact First Name']=np.where(df['Parental Contact']==1,df['Parental Contact Name_1'],df['Parental Contact Name_2'])

# %%
df['Parental Contact Full Name']=df['pupil last name']+","+df['Parental Contact First Name']

# %%
df['Parental Contact Email address']=df['Parental Contact First Name']+'.'+df['pupil last name']+'@'+df['Preferred Contact Employer']

# %%
df['Date of Birth']=pd.to_datetime(df['Date of Birth'])

# %%
admitted=dt.datetime.strptime('08-30-2015','%m-%d-%Y')

# %%
df['academic']=admitted-df['Date of Birth']

# %%
df['academic']= df['academic'] / np.timedelta64(1, 'Y')

# %%
df['Academic Year'] = df['academic'].apply(np.ceil).astype(int)

# %%
df=df.drop(['id', 'pupil first name', 'pupil last name', 'gender', 'Date of Birth',
       'Parental Contact Name_1', 'Parental Contact Name_2',
       'Preferred Contact Employer', 'Parental Contact','Parental Contact First Name','academic'],axis=1)

# %%
df.head(10)
# Out:
#          Pupils Name Parental Contact Full Name  \
# 0      Nellies,Ronna            Nellies,Purcell
# 1    Andriulis,Rusty          Andriulis,Vassili
# 2  Oakeshott,Roberta          Oakeshott,Haskell
# 3     Rubinfajn,Lola            Rubinfajn,Tresa
# 4    Benedtti,Kamila             Benedtti,Adela
# 5    Colebourn,Avery          Colebourn,Dalenna
# 6   Klimko,Valentino            Klimko,Onofredo
# 7      Shearwood,Cal            Shearwood,Berne
# 8      Truswell,King              Truswell,Evvy
# 9    Stichall,Towney            Stichall,Joyann
#
#   Parental Contact Email address  Academic Year
# 0         Purcell.Nellies@Demizz              2
# 1     Vassili.Andriulis@Brainbox              4
# 2     Haskell.Oakeshott@Centidel              4
# 3       Tresa.Rubinfajn@Edgeblab              4
# 4          Adela.Benedtti@Trudoo              4
# 5     Dalenna.Colebourn@Linktype              3
# 6    Onofredo.Klimko@Thoughtblab              1
# ...

# %% [markdown]
# ### End Of Code
